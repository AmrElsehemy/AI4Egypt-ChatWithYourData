# %%
import os
os.environ["OPENAI_API_KEY"] = '<openai-key>'  # set environment variable
openai_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# There are at least 10 big LLMs out there, OpenAI models are the most famous
# OpenAI have many models
#
# ![Screenshot 2023-07-19 at 10.23.20 AM.png](<attachment:Screenshot 2023-07-19 at 10.23.20 AM.png>)
#
# https://platform.openai.com/docs/models/overview

# %%
pip install --upgrade openai

# %%
pip install --upgrade langchain

# %%
openai_key = os.getenv("OPENAI_API_KEY")

# %%
import openai

embedding = openai.Embedding.create(
    api_key = openai_key,
    input="This is a query I want to know the vector embedding of", 
    model="text-embedding-ada-002"
)["data"][0]["embedding"]
embedding

# %% [markdown]
# Sample of Embeddings (the playground)

# %%
text = openai.Completion.create(
    api_key = openai_key,
    model="text-davinci-003",
    prompt="France is famous for its",
    max_tokens=15,
    temperature=1
)
text['choices'][0]['text']

# %%
# Example OpenAI Python library request
MODEL = "gpt-3.5-turbo"
response = openai.ChatCompletion.create(
    api_key = openai_key,
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Knock knock."},
        {"role": "assistant", "content": "Who's there?"},
        {"role": "user", "content": "Orange."},
    ],
    temperature=0,
)

response

# %%
response['choices'][0]['message']['content']

# %%
# example with a system message
response = openai.ChatCompletion.create(
    api_key = openai_key,
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain asynchronous programming in the style of the pirate Blackbeard."},
    ],
    temperature=0,
)

print(response['choices'][0]['message']['content'])

# %%
# An example of a system message that primes the assistant to explain concepts in great depth
response = openai.ChatCompletion.create(
    api_key = openai_key,
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a friendly and helpful teaching assistant. You explain concepts in great depth using simple terms, and you give examples to help people learn. At the end of each explanation, you ask a question to check for understanding"},
        {"role": "user", "content": "Can you explain how fractions work?"},
    ],
    temperature=0,
)

print(response["choices"][0]["message"]["content"])

# %%
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from langchain.chains import LLMChain

llm = OpenAI(temperature=0.9, openai_api_key=openai_key)
prompt = PromptTemplate(
    input_variables=["product"],
    template="Suggest 5 names for a company that makes {product}?",
)

chain = LLMChain(llm=llm, prompt=prompt)

chain.run("colorful socks")

# %%
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from langchain.chains import LLMChain

llm = OpenAI(temperature=0.9, openai_api_key=openai_key)
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good description for a company that makes {product}? in 20 words",
)

chain = LLMChain(llm=llm, prompt=prompt)

chain.run("colorful socks")

# %% [markdown]
# Use Case

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Langchain

# %% [markdown]
# QA and Chat over Documents
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
